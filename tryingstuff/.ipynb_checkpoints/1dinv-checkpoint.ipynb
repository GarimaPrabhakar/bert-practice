# %%
import numpy as np
import matplotlib.pyplot as plt

import pygimli as pg
from pygimli.viewer.mpl import drawModel1D
import pandas as pd

# %%
df = pd.read_csv("cowsns.csv")
ab2 = df["AB/2 [m]"]
rhoa = df["R [rho]"]

# %%
nlay = 20 # number of layers
lam = 200.  # (initial) regularization parameter
errPerc = 3.  # relative error of 3 percent=
ab2 = df["AB/2 [m]"]
rhoa = df["R [rho]"]
mn2 = ab2 / 3.  # MN/2 distance (potential electrodes)


def invert(nlay, ab2, mn2, lam, rhoa=rhoa, mscheme=0.5):
    print(2*max(rhoa))
    # initialize the forward modelling operator
    f = pg.core.DC1dModelling(nlay, ab2, mn2)

    transThk = pg.trans.TransLog()  # log-transform ensures thk>0
    transRho = pg.trans.TransLogLU(1, 2*max(rhoa))  # lower and upper bound
    transRhoa = pg.trans.TransLog()  # log transformation for data

    f.region(0).setTransModel(transThk)  # 0=thickness
    f.region(1).setTransModel(transRho)  # 1=resistivity

    paraDepth = max(ab2) / 3.  # rule-of-thumb for Wenner/Schlumberger
    f.region(0).setStartValue(paraDepth / nlay / 2)
    f.region(1).setStartValue(np.median(rhoa))

    inv = pg.core.Inversion(rhoa, f, transRhoa, True)  # data vector, fop, verbose
    inv.setRelativeError(errPerc / 100.0)  # alternative: setAbsoluteError in Ohmm
    inv.setLambda(lam)  # (initial) regularization parameter
    inv.setMarquardtScheme(mscheme)  # decrease lambda by factor 0.9
    #help(inv)
    print("optimized lambda value:", inv.getLambda(), lam)
    model = f.createStartVector()  # creates from region start value
    model[nlay] *= 1.5  # change default model by changing 2nd layer resistivity
    inv.setModel(model)
  
    model = inv.run()  # result is a pg.Vector, but compatible to numpy array
    res, thk = model[nlay-1:nlay*2-1], model[0:nlay-1]
    print('rrms={:.2f}%, chi^2={:.3f}'.format(inv.relrms(), inv.chi2()))

    fig, ax = plt.subplots(ncols=2, figsize=(8, 6))  # two-column figure
    #drawModel1D(ax[0], synthk, synres, plot='semilogx', color='r')
    drawModel1D(ax[0], thk, res, color='b')
    ax[0].grid(True, which='both')
    ax[0].set_ylabel('z (m)')
    ax[0].set_xlabel(r'$\rho$ ($\Omega$m)')
  
    ax[1].loglog(np.array(rhoa).reshape(len(rhoa),1), np.array(ab2).reshape(len(ab2),1), 'rx-', label='measured')
    ax[1].loglog(np.array(inv.response()).reshape(len(inv.response()),1), ab2, 'b-', label='fitted')

    ax[1].set_ylim((max(ab2), min(ab2)))  # downwards according to penetration
    ax[1].grid(True, which='both')
    ax[1].set_xlabel(r'$\rho_a$ ($\Omega$m)')
    ax[1].set_ylabel('AB/2 (m)')
    ax[1].legend(loc='best')
    plt.show()
    
    return model, inv.chi2()

model, chi2 = invert(len(rhoa)+1, ab2, mn2, lam, rhoa, 0.4)
# Out:
# 3243.694414
# optimized lambda value: 200.0 200.0
# min/max(dweight) = 33.3333/33.3333
# rrms=10.67%, chi^2=12.394
# use model trans from RegionManager
# min/max(dweight) = 33.3333/33.3333
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 25 x 25
# check Jacobian: wrong dimensions: (0x0) should be (12x25)  force: 1
# jacobian size invalid, forced recalc: 1
# calculating jacobian matrix (forced=1)...... 0.101 s
# min data = 398.315 max data = 1621.85 (12)
# min error = 0.03 max error = 0.03 (12)
# min response = 1123.97 max response = 1249.37 (12)
# calc without reference model
# 0: rms/rrms(data, response) = 406.216/70.963%
# 0: chi^2(data, response, error, log) = 235.01
# 0: Phi = 2820.11 + 50.9262 * 200 = 2820.11
# Iter: 0
# use local regularization
# solve CGLSCDWWtrans with lambda = 200
# Linesearch tau = 1
# 1: Model: min = 0.130982; max = 1567.5
# 1: Response: min = 775.376; max = 1235.27
# 1: rms/rrms(data, Response) = 372.292/42.0947%
# 1: chi^2(data, Response, error, log) = 156.764
# 1: Phi = 1881.17+50.2635*200=1881.17
# Iter: 1
# calculating jacobian matrix (forced=1)...... 0.072 s
# use local regularization
# solve CGLSCDWWtrans with lambda = 80
# Linesearch tau = 1
# 2: Model: min = 0.151342; max = 1751.35
# 2: Response: min = 772.975; max = 1207.88
# 2: rms/rrms(data, Response) = 284.841/38.485%
# 2: chi^2(data, Response, error, log) = 107.785
# 2: Phi = 1293.42+36.3598*80=1293.42
# Iter: 2
# calculating jacobian matrix (forced=1)...... 0.071 s
# use local regularization
# solve CGLSCDWWtrans with lambda = 32
# 3: LS newModel: min = 0.145298; max = 2246.89
# 3: LS newResponse: min = 798.497; max = 1488.34
# 3: rms/rrms(data, LS newResponse) = 209.048/41.4349%
# 3: chi^2(data, LS newResponse, error, log) = 98.1297
# 3: Phi = 1177.56+34.8154*32=1177.56
# Linesearch tau = 0.65
# 3: Model: min = 0.147386; max = 2079.16
# 3: Response: min = 711.495; max = 1375.78
# 3: rms/rrms(data, Response) = 192.26/32.1529%
# 3: chi^2(data, Response, error, log) = 69.4595
# 3: Phi = 833.514+33.6979*32=833.514
# Iter: 3
# calculating jacobian matrix (forced=1)...... 0.071 s
# use local regularization
# solve CGLSCDWWtrans with lambda = 12.8
# tau = 0. Trying parabolic line search with step length 0.3 ==> tau = 0.406663
# 4: LS newModel: min = 0.115246; max = 2527.96
# 4: LS newResponse: min = 758.876; max = 1588.25
# 4: rms/rrms(data, LS newResponse) = 198.318/39.0278%
# 4: chi^2(data, LS newResponse, error, log) = 90.5853
# 4: Phi = 1087.02+54.1814*12.8=1087.02
# Linesearch tau = 0.406663
# 4: Model: min = 0.133355; max = 2265.57
# 4: Response: min = 653.101; max = 1452.95
# 4: rms/rrms(data, Response) = 151.704/27.0374%
# 4: chi^2(data, Response, error, log) = 51.1737
# 4: Phi = 614.084+40.0449*12.8=614.084
# Iter: 4
# calculating jacobian matrix (forced=1)...... 0.07 s
# use local regularization
# solve CGLSCDWWtrans with lambda = 5.12
# Linesearch tau = 1
# 5: Model: min = 0.0846656; max = 2803.12
# 5: Response: min = 588.956; max = 1537.29
# 5: rms/rrms(data, Response) = 110.704/21.3145%
# 5: chi^2(data, Response, error, log) = 33.7748
# 5: Phi = 405.297+84.168*5.12=405.297
# Iter: 5
# calculating jacobian matrix (forced=1)...... 0.071 s
# use local regularization
# solve CGLSCDWWtrans with lambda = 2.048
# Linesearch tau = 1
# 6: Model: min = 0.0494001; max = 3088.45
# 6: Response: min = 462.76; max = 1528.92
# 6: rms/rrms(data, Response) = 100.472/11.2146%
# 6: chi^2(data, Response, error, log) = 13.142
# 6: Phi = 157.704+138.687*2.048=157.704
# Iter: 6
# calculating jacobian matrix (forced=1)...... 0.072 s
# use local regularization
# solve CGLSCDWWtrans with lambda = 0.8192
# 7: LS newModel: min = 0.00240144; max = 3170.58
# 7: LS newResponse: min = 410.854; max = 1657.5
# 7: rms/rrms(data, LS newResponse) = 125.783/12.1623%
# 7: chi^2(data, LS newResponse, error, log) = 16.3059
# 7: Phi = 195.67+237.551*0.8192=195.67
# Linesearch tau = 0.3
# 7: Model: min = 0.0199412; max = 3119.57
# 7: Response: min = 456.065; max = 1541.08
# 7: rms/rrms(data, Response) = 99.4195/10.8892%
# 7: chi^2(data, Response, error, log) = 12.6321
# 7: Phi = 151.585+163.724*0.8192=151.585
# Iter: 7
# calculating jacobian matrix (forced=1)...... 0.071 s
# use local regularization
# solve CGLSCDWWtrans with lambda = 0.32768
# tau = 0.01. Trying parabolic line search with step length 0.3 ==> tau = 0.149751
# 8: LS newModel: min = 9.66049e-05; max = 3197.13
# 8: LS newResponse: min = 133.097; max = 2483.19
# 8: rms/rrms(data, LS newResponse) = 736.155/73.4909%
# 8: chi^2(data, LS newResponse, error, log) = 554.156
# 8: Phi = 6649.87+370.368*0.32768=6649.87
# Linesearch tau = 0.149751
# 8: Model: min = 0.00897666; max = 3136.34
# 8: Response: min = 449.202; max = 1551.12
# 8: rms/rrms(data, Response) = 100.022/10.6677%
# 8: chi^2(data, Response, error, log) = 12.3937
# 8: Phi = 148.725+186.434*0.32768=148.725
# Reached data fit criteria (delta phi < 2%). Stop.
# /opt/anaconda3/conda-bld/pgcore_1645178403028/work/gimli/core/src/regionManager.h:182		void GIMLI::Region::setStartValue(double)  is deprecated
# /opt/anaconda3/conda-bld/pgcore_1645178403028/work/gimli/core/src/regionManager.h:182		void GIMLI::Region::setStartValue(double)  is deprecated
# /opt/anaconda3/conda-bld/pgcore_1645178403028/work/gimli/core/src/modellingbase.cpp:523		GIMLI::RVector GIMLI::ModellingBase::createStartVector()  is deprecated

# %%
df
# Out:
#     AB/2 [m]      R [rho]
# 0        1.0   888.285323
# 1        1.5  1143.539726
# 2        2.0  1353.633735
# 3        3.0  1621.847207
# 4        4.0  1608.102740
# 5        5.0  1611.849089
# 6        6.0  1306.187832
# 7        7.0  1101.167495
# 8        8.0   941.299699
# 9        9.0   816.861214
# 10      10.0   460.659585
# 11      11.0   398.314679

# %%
model, chi2 = invert(3, ab2, mn2, lam, rhoa, 0.4)
print(model, chi2)
# Out:
# 3243.694414
# optimized lambda value: 200.0 200.0
# rrms=10.47%, chi^2=12.041
# min/max(dweight) = 33.3333/33.3333
# use model trans from RegionManager
# min/max(dweight) = 33.3333/33.3333
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 5 x 5
# check Jacobian: wrong dimensions: (0x0) should be (12x5)  force: 1
# jacobian size invalid, forced recalc: 1
# calculating jacobian matrix (forced=1)...... 0.005 s
# min data = 398.315 max data = 1621.85 (12)
# min error = 0.03 max error = 0.03 (12)
# min response = 1152.26 max response = 1286.84 (12)
# calc without reference model
# 0: rms/rrms(data, response) = 381.364/73.1206%
# 0: chi^2(data, response, error, log) = 227.438
# 0: Phi = 2729.26 + 1.30361 * 200 = 2729.26
# Iter: 0
# use local regularization
# solve CGLSCDWWtrans with lambda = 200
# Linesearch tau = 1
# 1: Model: min = 0.662821; max = 2196.14
# 1: Response: min = 817.316; max = 1330.86
# 1: rms/rrms(data, Response) = 270.513/41.842%
# 1: chi^2(data, Response, error, log) = 112.767
# 1: Phi = 1353.21+3.051*200=1353.21
# Iter: 1
# calculating jacobian matrix (forced=1)...... 0.005 s
# use local regularization
# solve CGLSCDWWtrans with lambda = 80
# tau = 0. Trying parabolic line search with step length 0.3 ==> tau = 0.263606
# 2: LS newModel: min = 0.762884; max = 2572.77
# 2: LS newResponse: min = 947.383; max = 1654.78
# 2: rms/rrms(data, LS newResponse) = 462.352/87.6613%
# 2: chi^2(data, LS newResponse, error, log) = 292.771
# 2: Phi = 3513.26+10.6925*80=3513.26
# Linesearch tau = 0.263606
# 2: Model: min = 0.687849; max = 2305.71
# 2: Response: min = 767.694; max = 1393
# 2: rms/rrms(data, Response) = 221.652/36.9377%
# 2: chi^2(data, Response, error, log) = 87.8142
# 2: Phi = 1053.77+4.41561*80=1053.77
# Iter: 2
# calculating jacobian matrix (forced=1)...... 0.006 s
# use local regularization
# solve CGLSCDWWtrans with lambda = 32
# tau = 0. Trying parabolic line search with step length 0.3 ==> tau = 0.218289
# 3: LS newModel: min = 0.545115; max = 2645.32
# 3: LS newResponse: min = 954.773; max = 1782.42
# 3: rms/rrms(data, LS newResponse) = 504.225/91.7547%
# 3: chi^2(data, LS newResponse, error, log) = 318.466
# 3: Phi = 3821.6+17.3228*32=3821.6
# Linesearch tau = 0.218289
# 3: Model: min = 0.653799; max = 2388.77
# 3: Response: min = 721.381; max = 1442.46
# 3: rms/rrms(data, Response) = 184.557/32.7369%
# 3: chi^2(data, Response, error, log) = 70.3335
# 3: Phi = 844.002+6.43963*32=844.002
# Iter: 3
# calculating jacobian matrix (forced=1)...... 0.008 s
# use local regularization
# solve CGLSCDWWtrans with lambda = 12.8
# tau = 0. Trying parabolic line search with step length 0.3 ==> tau = 0.213242
# 4: LS newModel: min = 0.429676; max = 2725.26
# 4: LS newResponse: min = 963.73; max = 1774.76
# 4: rms/rrms(data, LS newResponse) = 419.267/74.6528%
# 4: chi^2(data, LS newResponse, error, log) = 244.617
# 4: Phi = 2935.41+24.9367*12.8=2935.41
# Linesearch tau = 0.213242
# 4: Model: min = 0.597819; max = 2470.88
# 4: Response: min = 679.147; max = 1483.41
# 4: rms/rrms(data, Response) = 156.175/29.0881%
# 4: chi^2(data, Response, error, log) = 57.2444
# 4: Phi = 686.933+9.3373*12.8=686.933
# Iter: 4
# calculating jacobian matrix (forced=1)...... 0.006 s
# use local regularization
# solve CGLSCDWWtrans with lambda = 5.12
# tau = 0. Trying parabolic line search with step length 0.3 ==> tau = 0.241351
# 5: LS newModel: min = 0.385827; max = 2868.98
# 5: LS newResponse: min = 868.045; max = 1716.95
# 5: rms/rrms(data, LS newResponse) = 289.07/52.287%
# 5: chi^2(data, LS newResponse, error, log) = 145.959
# 5: Phi = 1751.51+35.9152*5.12=1751.51
# Linesearch tau = 0.241351
# 5: Model: min = 0.537861; max = 2588.05
# 5: Response: min = 640.809; max = 1522.93
# 5: rms/rrms(data, Response) = 133.837/25.8798%
# 5: chi^2(data, Response, error, log) = 46.9064
# 5: Phi = 562.877+14.1214*5.12=562.877
# Iter: 5
# calculating jacobian matrix (forced=1)...... 0.005 s
# use local regularization
# solve CGLSCDWWtrans with lambda = 2.048
# Linesearch tau = 1
# 6: Model: min = 0.381986; max = 3077.93
# 6: Response: min = 612.115; max = 1567.73
# 6: rms/rrms(data, Response) = 119.125/23.8332%
# 6: chi^2(data, Response, error, log) = 40.5494
# 6: Phi = 486.593+55.9446*2.048=486.593
# Iter: 6
# calculating jacobian matrix (forced=1)...... 0.005 s
# use local regularization
# solve CGLSCDWWtrans with lambda = 0.8192
# 7: LS newModel: min = 0.0650385; max = 3203.43
# 7: LS newResponse: min = 430.791; max = 1550.93
# 7: rms/rrms(data, LS newResponse) = 107.83/10.4405%
# 7: chi^2(data, LS newResponse, error, log) = 12.8026
# 7: Phi = 153.631+90.6346*0.8192=153.631
# Linesearch tau = 0.88
# 7: Model: min = 0.0804333; max = 3195.86
# 7: Response: min = 449.681; max = 1555.98
# 7: rms/rrms(data, Response) = 97.3886/10.5539%
# 7: chi^2(data, Response, error, log) = 12.0569
# 7: Phi = 144.682+85.5378*0.8192=144.682
# Iter: 7
# calculating jacobian matrix (forced=1)...... 0.005 s
# use local regularization
# solve CGLSCDWWtrans with lambda = 0.32768
# tau = 0.01. Trying parabolic line search with step length 0.3 ==> tau = 0.150015
# 8: LS newModel: min = 0.00041543; max = 3218.18
# 8: LS newResponse: min = 214.731; max = 2125.56
# 8: rms/rrms(data, LS newResponse) = 479.877/47.2495%
# 8: chi^2(data, LS newResponse, error, log) = 222.934
# 8: Phi = 2675.2+226.932*0.32768=2675.2
# Linesearch tau = 0.150015
# 8: Model: min = 0.0365057; max = 3200.15
# 8: Response: min = 446.061; max = 1557.59
# 8: rms/rrms(data, Response) = 98.6116/10.4721%
# 8: chi^2(data, Response, error, log) = 12.0408
# 8: Phi = 144.489+99.256*0.32768=144.489
# Reached data fit criteria (delta phi < 2%). Stop.
# /opt/anaconda3/conda-bld/pgcore_1645178403028/work/gimli/core/src/regionManager.h:182		void GIMLI::Region::setStartValue(double)  is deprecated
# /opt/anaconda3/conda-bld/pgcore_1645178403028/work/gimli/core/src/regionManager.h:182		void GIMLI::Region::setStartValue(double)  is deprecated
# /opt/anaconda3/conda-bld/pgcore_1645178403028/work/gimli/core/src/modellingbase.cpp:523		GIMLI::RVector GIMLI::ModellingBase::createStartVector()  is deprecated
# 5 [0.03650572353501794, 1.842947280313914, 51.87042465528825, 3200.1485897711877, 3.338516283232797] 12.040772094167098
