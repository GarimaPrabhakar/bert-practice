# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !conda install --yes sympy
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/gprabhakar/miniconda3
#
#   added / updated specs:
#     - sympy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.12.7  |       h033912b_0         142 KB  conda-forge
#     certifi-2022.12.7          |     pyhd8ed1ab_0         147 KB  conda-forge
#     conda-22.11.1              |   py39h6e9494a_1         874 KB  conda-forge
#     gmpy2-2.1.2                |   py39h2da61ea_1         166 KB  conda-forge
#     mpc-1.2.1                  |       hbb51d92_0         103 KB  conda-forge
#     mpmath-1.2.1               |     pyhd8ed1ab_0         437 KB  conda-forge
#     openssl-3.0.7              |       hfd90126_1         2.2 MB  conda-forge
#     ruamel.yaml-0.17.21        |   py39ha30fb19_2         173 KB  conda-forge
#     ruamel.yaml.clib-0.2.7     |   py39ha30fb19_1         118 KB  conda-forge
#     sympy-1.11.1               |   py39h6e9494a_2        11.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        16.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   gmpy2              conda-forge/osx-64::gmpy2-2.1.2-py39h2da61ea_1 None
#   mpc                conda-forge/osx-64::mpc-1.2.1-hbb51d92_0 None
#   mpmath             conda-forge/noarch::mpmath-1.2.1-pyhd8ed1ab_0 None
#   ruamel.yaml        conda-forge/osx-64::ruamel.yaml-0.17.21-py39ha30fb19_2 None
#   ruamel.yaml.clib   conda-forge/osx-64::ruamel.yaml.clib-0.2.7-py39ha30fb19_1 None
#   sympy              conda-forge/osx-64::sympy-1.11.1-py39h6e9494a_2 None
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2022.9.24-h033912b_0 --> 2022.12.7-h033912b_0 None
#   certifi                            2022.9.24-pyhd8ed1ab_0 --> 2022.12.7-pyhd8ed1ab_0 None
#   conda                               22.9.0-py39h6e9494a_2 --> 22.11.1-py39h6e9494a_1 None
#   openssl                                  3.0.7-hfd90126_0 --> 3.0.7-hfd90126_1 None
#
#
#
# Downloading and Extracting Packages
# mpmath-1.2.1         | 437 KB    | ##################################### | 100%
# ca-certificates-2022 | 142 KB    | ##################################### | 100%
# certifi-2022.12.7    | 147 KB    | ##################################### | 100%
# gmpy2-2.1.2          | 166 KB    | ##################################### | 100%
# ruamel.yaml-0.17.21  | 173 KB    | ##################################### | 100%
# conda-22.11.1        | 874 KB    | ##################################### | 100%
# openssl-3.0.7        | 2.2 MB    | ##################################### | 100%
# ruamel.yaml.clib-0.2 | 118 KB    | ##################################### | 100%
# sympy-1.11.1         | 11.8 MB   | ##################################### | 100%
# mpc-1.2.1            | 103 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Retrieving notices: ...working... done

# %%
# starting variables
x = np.linspace(-10, 10)
z = np.linspace(-10, 0)
y = np.linspace(-10, 10)

xx, zz = np.meshgrid(x, z)

i = 0.1 # Inject 100 mA of current

# %%
# one layer model potential distribution

rho = 100 # Resistivity of soil
r = (xx**2 + zz**2)**0.5

v = rho*i/(2*3.14159*r)

plt.contourf(np.log(v), extent=[min(x),max(x),min(z),max(z)], aspect='auto')
cbar = plt.colorbar()
plt.title("One layer Potential Distribution for One Current Source")
plt.xlabel("x (m)")
plt.ylabel("z (m)")
cbar.ax.set_ylabel('log(V)', rotation=270)
# Out:
# /var/folders/_7/x_mxrhfx0gq6pt61nr_x9t880000gn/T/ipykernel_2431/1671989119.py:8: UserWarning: The following kwargs were not used by contour: 'aspect'
#   plt.contourf(np.log(v), extent=[min(x),max(x),min(z),max(z)], aspect='auto')
# Text(0, 0.5, 'log(V)')

# %%
# put the current source at -4 m and add a current sink at +4 m.
rho = 100 # Resistivity of soil

# source
rsource = ((xx - 4)**2 + zz**2)**0.5
vsource = rho*i/(2*3.14159*rsource)

# sink
rsink = ((xx + 4)**2 + zz**2)**0.5
vsink = -1*rho*i/(2*3.14159*rsink)

plt.contourf((vsource + vsink)[:40,:], extent=[min(x),max(x),-8,max(z)], aspect='auto')
cbar = plt.colorbar()
plt.title("One layer Potential Distribution \nfor A Current Source and Sink")
plt.xlabel("x (m)")
plt.ylabel("z (m)")
cbar.ax.set_ylabel('log(V)', rotation=270)
# Out:
# /var/folders/_7/x_mxrhfx0gq6pt61nr_x9t880000gn/T/ipykernel_2431/2460203445.py:12: UserWarning: The following kwargs were not used by contour: 'aspect'
#   plt.contourf((vsource + vsink)[:40,:], extent=[min(x),max(x),-8,max(z)], aspect='auto')
# Text(0, 0.5, 'log(V)')

# %%
# two layers
from scipy.special import j0
from scipy.integrate import quad

rhomap = [[100, 1], [200, np.inf]]

r = 3
def integrand(lamb,rhomap=rhomap, r=3):
    # print(r)
    p1 = rhomap[0][0]
    h1 = rhomap[0][1]
    
    p2 = rhomap[1][0]
    
    k1 = (p2 - p1)/(p2 + p1)
    return k1*np.exp(-2*lamb*h1)*j0(lamb*r)/(1 - k1*np.exp(-2*lamb*h1))



lamb = np.linspace(0, 1000)
integrand.r = 5
print(integrand.r)
ker = integrand(lamb, rhomap)

# plt.imshow(ker)
# plt.colorbar()

quad(integrand, 0, np.inf)
# Out:
# 5
# (0.0475593949939177, 1.3633226383340906e-08)

# %%
# ahhh. retrying the integration with sympy.
import sympy

p1 = rhomap[0][0]
h1 = rhomap[0][1]
    
p2 = rhomap[1][0]
    
k1 = (p2 - p1)/(p2 + p1)
sympy.integrate(k1*np.exp(-2*lamb*h1)*j0(lamb*r)/(1 - k1*np.exp(-2*lamb*h1)), lamb)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 10>()
#       7 p2 = rhomap[1][0]
#       9 k1 = (p2 - p1)/(p2 + p1)
# ---> 10 sympy.integrate(k1*np.exp(-2*lamb*h1)*j0(lamb*r)/(1 - k1*np.exp(-2*lamb*h1)), lamb)
#
# NameError: name 'r' is not defined
